# %% [markdown]
# # Object Oriented Programming

# %% [markdown]
# First of all,
# it's a different style of writing code.

# %%
L = [1,2,3,4]

# %%
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9560/3930800027.py in <module>
# ----> 1 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
city = 'Warangal'

# %%
city.append()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9560/840243280.py in <module>
# ----> 1 city.append()
#
# AttributeError: 'str' object has no attribute 'append'

# %%
a = 3

# %%
a.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9560/2984306047.py in <module>
# ----> 1 a.upper()
#
# AttributeError: 'int' object has no attribute 'upper'

# %% [markdown]
# ## Everything in python is an Object

# %% [markdown]
# ## But what is an Object?

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 2

# %%
type(a)
# Out:
# int

# %%
L
# Out:
# [1, 2, 3, 4]

# %%
type(L)
# Out:
# list

# %%
L = 2

# %%
type(L)
# Out:
# int

# %% [markdown]
# # Class

# %% [markdown]
# `Class is a blueprint.`
#
# `Blueprint of how an object will behave.`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Name of the class should be in `PascalCase`

# %% [markdown]
# Names of data and Functions in the class should be in `Snake_case`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Object

# %% [markdown]
# `Object is an instance of the class.`

# %%
L = [1,2,3] # Object Literal

# %%
L = list()

# %%
L
# Out:
# []

# %%
city = str()
city
# Out:
# ''

# %% [markdown]
# ###### Methods:

# %% [markdown]
# `Methods are basically functions which are written inside a class.`

# %% [markdown]
# Function is General, anybody can call it and use it.

# %% [markdown]
# But Method is very specific. It can be used or called only by its class.

# %%
class Atm:
    
    # Constructor
    
    def __init__(self):
        
        self.pin = ""
        self.balance = 0
        
        self.menu()
    
    def menu(self):
        user_input = input("""
                        Hello, How would you like to Proceed?
                        1. Enter 1 to Create Pin
                        2. Enter 2 to deposit
                        3. Enter 3 to withdraw
                        4. Enter 4 to Check Balance
                        5. Enter 5 to exit
        """)
        
        if user_input == "1":
            self.create_pin()
        elif user_input == '2':
            self.deposit()
        elif user_input == '3':
            self.withdraw()
        elif user_input == '4':
            self.check_balance()
        else:
            print('Hope to See you again')
        
    
    def create_pin(self):
        
        self.pin = input('Enter your pin')
        print('Pin set successfully')
        
    def deposit(self):
        
        temp = input('Enter your pin')
        if temp == self.pin:
            amount = int(input('Enter the amount'))
            self.balance = self.balance + amount
        else:
            print('Invalid pin')
            
    def withdraw(self):
        
            temp = input('Enter your pin')
            if temp == self.pin:
                amount = int(input('Enter the amount'))
                if amount < self.balance:
                    self.balance = self.balance - amount
                    print('Withdrawal Successful')
                else:
                    print('insufficient funds')
            else:
                print('Invalid pin')
                
                
    def check_balance(self):
        
        
            temp = input('Enter your pin')
            if temp == self.pin:
                print(self.balance)
            else:
                print('Invalid pin')

# %%
sbi = Atm()
# Out:
#                         Hello, How would you like to Proceed?
#                         1. Enter 1 to Create Pin
#                         2. Enter 2 to deposit
#                         3. Enter 3 to withdraw
#                         4. Enter 4 to Check Balance
#                         5. Enter 5 to exit
#         1
# Enter your pin1234
# Pin set successfully

# %%
sbi.deposit()
# Out:
# Enter your pin1234
# Enter the amount500000000

# %%
sbi.check_balance()
# Out:
# Enter your pin1234
# 500000000

# %%
sbi.withdraw()
# Out:
# Enter your pin1234
# Enter the amount5
# Withdrawal Successful

# %%
sbi.check_balance()
# Out:
# Enter your pin1234
# 499999995

# %%
sbi.deposit()
# Out:
# Enter your pin1234
# Enter the amount5

# %%
sbi.check_balance()
# Out:
# Enter your pin1234
# 500000000

# %%
hdfc = Atm()
# Out:
#                         Hello, How would you like to Proceed?
#                         1. Enter 1 to Create Pin
#                         2. Enter 2 to deposit
#                         3. Enter 3 to withdraw
#                         4. Enter 4 to Check Balance
#                         5. Enter 5 to exit
#         1
# Enter your pin9999
# Pin set successfully

# %%
hdfc.check_balance()
# Out:
# Enter your pin9999
# 0

# %%
hdfc.balance
# Out:
# 0

# %%
sbi.balance
# Out:
# 500000000

# %%
sbi.withdraw
# Out:
# <bound method Atm.withdraw of <__main__.Atm object at 0x000001C529553B80>>

# %%
dir(int)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
# ...
